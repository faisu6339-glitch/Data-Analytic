# %%
 import pandas as pd

# %%
csv_1=pd.read_csv("locations.csv")
csv_1
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...

# %%
csv_2=pd.read_csv("italy-covid-daywise.csv")
csv_2
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
#Finding Specific ROWS

# %%
csv_2=pd.read_csv("italy-covid-daywise.csv",nrows=9)
csv_2
# Out:
#          date  new_cases  new_deaths  new_tests
# 0  2019-12-31        0.0         0.0        NaN
# 1  2020-01-01        0.0         0.0        NaN
# 2  2020-01-02        0.0         0.0        NaN
# 3  2020-01-03        0.0         0.0        NaN
# 4  2020-01-04        0.0         0.0        NaN
# 5  2020-01-05        0.0         0.0        NaN
# 6  2020-01-06        0.0         0.0        NaN
# 7  2020-01-07        0.0         0.0        NaN
# 8  2020-01-08        0.0         0.0        NaN

# %%
#Finding Specific Columns by Name

# %%
csv_2=pd.read_csv("italy-covid-daywise.csv",usecols=["date","new_tests"])
csv_2
# Out:
#            date  new_tests
# 0    2019-12-31        NaN
# 1    2020-01-01        NaN
# 2    2020-01-02        NaN
# 3    2020-01-03        NaN
# 4    2020-01-04        NaN
# ..          ...        ...
# 243  2020-08-30    53541.0
# 244  2020-08-31    42583.0
# 245  2020-09-01    54395.0
# 246  2020-09-02        NaN
# 247  2020-09-03        NaN
#
# [248 rows x 2 columns]

# %%
csv_2=pd.read_csv("italy-covid-daywise.csv",usecols=[0,2])
csv_2
# Out:
#            date  new_deaths
# 0    2019-12-31         0.0
# 1    2020-01-01         0.0
# 2    2020-01-02         0.0
# 3    2020-01-03         0.0
# 4    2020-01-04         0.0
# ..          ...         ...
# 243  2020-08-30         1.0
# 244  2020-08-31         4.0
# 245  2020-09-01         6.0
# 246  2020-09-02         8.0
# 247  2020-09-03         6.0
#
# [248 rows x 2 columns]

# %%
#Skip rows

# %%
csv_2=pd.read_csv("italy-covid-daywise.csv",skiprows=[0])
csv_2
# Out:
#      2019-12-31     0.0  0.0.1  Unnamed: 3
# 0    2020-01-01     0.0    0.0         NaN
# 1    2020-01-02     0.0    0.0         NaN
# 2    2020-01-03     0.0    0.0         NaN
# 3    2020-01-04     0.0    0.0         NaN
# 4    2020-01-05     0.0    0.0         NaN
# ..          ...     ...    ...         ...
# 242  2020-08-30  1444.0    1.0     53541.0
# 243  2020-08-31  1365.0    4.0     42583.0
# 244  2020-09-01   996.0    6.0     54395.0
# 245  2020-09-02   975.0    8.0         NaN
# 246  2020-09-03  1326.0    6.0         NaN
#
# [247 rows x 4 columns]

# %%
#Making Index

# %%
csv_1=pd.read_csv("locations.csv",index_col="location")
csv_1
# Out:
#               continent    population  life_expectancy  \
# location
# Afghanistan        Asia  3.892834e+07            64.83
# Albania          Europe  2.877800e+06            78.57
# Algeria          Africa  4.385104e+07            76.88
# Andorra          Europe  7.726500e+04            83.73
# Angola           Africa  3.286627e+07            61.15
# ...                 ...           ...              ...
# Yemen              Asia  2.982597e+07            66.12
# Zambia           Africa  1.838396e+07            63.89
# Zimbabwe         Africa  1.486293e+07            61.49
# World               NaN  7.794799e+09            72.58
# International       NaN           NaN              NaN
#
#                hospital_beds_per_thousand  gdp_per_capita
# location
# Afghanistan                         0.500        1803.987
# Albania                             2.890       11803.431
# Algeria                             1.900       13913.839
# ...

# %%
#Making Header

# %%
csv_1=pd.read_csv("locations.csv",header=2)
csv_1
# Out:
#                  Albania         Europe     2877800.0  78.57   2.89  11803.431
# 0                Algeria         Africa  4.385104e+07  76.88  1.900  13913.839
# 1                Andorra         Europe  7.726500e+04  83.73    NaN        NaN
# 2                 Angola         Africa  3.286627e+07  61.15    NaN   5819.495
# 3               Anguilla  North America  1.500200e+04  81.88    NaN        NaN
# 4    Antigua and Barbuda  North America  9.792800e+04  77.02  3.800  21490.943
# ..                   ...            ...           ...    ...    ...        ...
# 205                Yemen           Asia  2.982597e+07  66.12  0.700   1479.147
# 206               Zambia         Africa  1.838396e+07  63.89  2.000   3689.251
# 207             Zimbabwe         Africa  1.486293e+07  61.49  1.700   1899.775
# 208                World            NaN  7.794799e+09  72.58  2.705  15469.207
# 209        International            NaN           NaN    NaN    NaN        NaN
#
# [210 rows x 6 columns]

# %%
#Creating New Heading

# %%
csv_5=pd.read_csv("locations.csv",names=["col1""col2","col3","col4","col5","col6"])
csv_5
# Out:
#                 col1col2          col3             col4  \
# location       continent    population  life_expectancy
# Afghanistan         Asia    38928341.0            64.83
# Albania           Europe     2877800.0            78.57
# Algeria           Africa    43851043.0            76.88
# Andorra           Europe       77265.0            83.73
# ...                  ...           ...              ...
# Yemen               Asia    29825968.0            66.12
# Zambia            Africa    18383956.0            63.89
# Zimbabwe          Africa    14862927.0            61.49
# World                NaN  7794798729.0            72.58
# International        NaN           NaN              NaN
#
#                                      col5                col6
# location       hospital_beds_per_thousand      gdp_per_capita
# Afghanistan                           0.5            1803.987
# Albania                              2.89           11803.431
# ...

# %%
#Deleing Header and using prefix

# %%
csv_1=pd.read_csv("locations.csv")
csv_1
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...

# %%
csv_5=pd.read_csv("locations.csv",header=None)
csv_5
# Out:
#                  0          1             2                3  \
# 0         location  continent    population  life_expectancy
# 1      Afghanistan       Asia    38928341.0            64.83
# 2          Albania     Europe     2877800.0            78.57
# 3          Algeria     Africa    43851043.0            76.88
# 4          Andorra     Europe       77265.0            83.73
# ..             ...        ...           ...              ...
# 208          Yemen       Asia    29825968.0            66.12
# 209         Zambia     Africa    18383956.0            63.89
# 210       Zimbabwe     Africa    14862927.0            61.49
# 211          World        NaN  7794798729.0            72.58
# 212  International        NaN           NaN              NaN
#
#                               4                   5
# 0    hospital_beds_per_thousand      gdp_per_capita
# 1                           0.5            1803.987
# 2                          2.89           11803.431
# ...

# %%
#Changing type of the data values

# %%
csv_1=pd.read_csv("locations.csv")
csv_1
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...

# %%
csv_1=pd.read_csv("locations.csv",dtype={"life_expectancy":"float"})
csv_1
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...
