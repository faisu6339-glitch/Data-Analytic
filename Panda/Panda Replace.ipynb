# %%
#Replace

# %%
import pandas as pd

# %%
var=pd.read_csv('locations.csv')
var
# Out:
#                location      continent   population  life_expectancy  \
# 0           Afghanistan           Asia   38928341.0            64.83
# 1               Albania         Europe    2877800.0            78.57
# 2                   NaN            NaN          NaN              NaN
# 3                   NaN            NaN          NaN              NaN
# 4                Angola         Africa   32866268.0            61.15
# 5                   NaN            NaN          NaN              NaN
# 6   Antigua and Barbuda  North America      97928.0            77.02
# 7             Argentina  South America   45195777.0            76.67
# 8               Armenia           Asia    2963234.0            75.09
# 9                 Aruba  North America     106766.0            76.29
# 10            Australia        Oceania   25499881.0            83.44
# 11              Austria         Europe    9006400.0            81.54
# 12           Azerbaijan           Asia   10139175.0            73.00
# ...

# %%
#Replacing the values

# %%
var.replace(to_replace="Afghanistan"	,value="Dubai")
# Out:
#                location      continent   population  life_expectancy  \
# 0                 Dubai           Asia   38928341.0            64.83
# 1               Albania         Europe    2877800.0            78.57
# 2                   NaN            NaN          NaN              NaN
# 3                   NaN            NaN          NaN              NaN
# 4                Angola         Africa   32866268.0            61.15
# 5                   NaN            NaN          NaN              NaN
# 6   Antigua and Barbuda  North America      97928.0            77.02
# 7             Argentina  South America   45195777.0            76.67
# 8               Armenia           Asia    2963234.0            75.09
# 9                 Aruba  North America     106766.0            76.29
# 10            Australia        Oceania   25499881.0            83.44
# 11              Austria         Europe    9006400.0            81.54
# 12           Azerbaijan           Asia   10139175.0            73.00
# ...

# %%
#Replacing Alphabetic letter

# %%
var.replace("[A-Za-z]","Aaliya Fatma",regex=True)
# Out:
#                                              location  \
# 0   Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 1   Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 2                                                 NaN
# 3                                                 NaN
# 4   Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 5                                                 NaN
# 6   Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 7   Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 8   Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 9   Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 10  Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 11  Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 12  Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 13  Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 14  Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# 15  Aaliya FatmaAaliya FatmaAaliya FatmaAaliya Fat...
# ...

# %%
var.replace({"continent":'[A-Za-z]'},22,regex=True)
# Out:
#                location  continent   population  life_expectancy  \
# 0           Afghanistan       22.0   38928341.0            64.83
# 1               Albania       22.0    2877800.0            78.57
# 2                   NaN        NaN          NaN              NaN
# 3                   NaN        NaN          NaN              NaN
# 4                Angola       22.0   32866268.0            61.15
# 5                   NaN        NaN          NaN              NaN
# 6   Antigua and Barbuda       22.0      97928.0            77.02
# 7             Argentina       22.0   45195777.0            76.67
# 8               Armenia       22.0    2963234.0            75.09
# 9                 Aruba       22.0     106766.0            76.29
# 10            Australia       22.0   25499881.0            83.44
# 11              Austria       22.0    9006400.0            81.54
# 12           Azerbaijan       22.0   10139175.0            73.00
# ...

# %%
var.replace(1,method="ffill")
# Out:
# C:\Users\MAA\AppData\Local\Temp\ipykernel_1552\4173063640.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var.replace(1,method="ffill")
#                location      continent   population  life_expectancy  \
# 0           Afghanistan           Asia   38928341.0            64.83
# 1               Albania         Europe    2877800.0            78.57
# 2                   NaN            NaN          NaN              NaN
# 3                   NaN            NaN          NaN              NaN
# 4                Angola         Africa   32866268.0            61.15
# 5                   NaN            NaN          NaN              NaN
# 6   Antigua and Barbuda  North America      97928.0            77.02
# 7             Argentina  South America   45195777.0            76.67
# 8               Armenia           Asia    2963234.0            75.09
# 9                 Aruba  North America     106766.0            76.29
# ...

# %%
#Forward filling the data

# %%
var.replace("Belgium",method="ffill")
# Out:
# C:\Users\MAA\AppData\Local\Temp\ipykernel_1552\4188030305.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var.replace("Belgium",method="ffill")
#                location      continent   population  life_expectancy  \
# 0           Afghanistan           Asia   38928341.0            64.83
# 1               Albania         Europe    2877800.0            78.57
# 2                   NaN            NaN          NaN              NaN
# 3                   NaN            NaN          NaN              NaN
# 4                Angola         Africa   32866268.0            61.15
# 5                   NaN            NaN          NaN              NaN
# 6   Antigua and Barbuda  North America      97928.0            77.02
# 7             Argentina  South America   45195777.0            76.67
# 8               Armenia           Asia    2963234.0            75.09
# ...

# %%
var.replace()
