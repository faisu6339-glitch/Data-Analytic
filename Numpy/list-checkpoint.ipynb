# %%
fruits = ['apple', 'banana', 'cherry']

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
type(fruits)
# Out:
# list

# %%
a_list=[67,'faisal',None,5.76]

# %%
a_list
# Out:
# [67, 'faisal', None, 5.76]

# %%
len(fruits)
# Out:
# 3

# %%
print("Number of fruits:", len(fruits))
# Out:
# Number of fruits: 3

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits = ['apple', 'banana', 'cherry' ,'Mango']

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'Mango']

# %%
fruits[0]='blueberry'

# %%
fruits
# Out:
# ['blueberry', 'banana', 'cherry', 'Mango']

# %%
fruits.append('Dates')

# %%
fruits
# Out:
# ['blueberry', 'banana', 'cherry', 'Mango', 'Dates']

# %%
fruits.insert(4,'banana')

# %%
fruits.pop(1)
# Out:
# 'banana'

# %%
'cherry' in fruits
# Out:
# True

# %%
more_fruits = fruits + ['pineapple', 'tomato', 'guava'] + ['dates', 'banana']

# %%
more_fruits
# Out:
# ['apple',
#  'cherry',
#  'banana',
#  'pineapple',
#  'tomato',
#  'guava',
#  'dates',
#  'banana']

# %%
more_fruits_copy = more_fruits.copy()

# %%
more_fruits_copy
# Out:
# ['apple',
#  'cherry',
#  'banana',
#  'pineapple',
#  'tomato',
#  'guava',
#  'dates',
#  'banana']
