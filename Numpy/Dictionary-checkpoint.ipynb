# %%
person1 = {
    'name': 'John Doe',
    'sex': 'Male',
    'age': 32,
    'married': True
}

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
person2 = dict(name='Jane Judy', sex='Female', age=28, married=False)

# %%
person2
# Out:
# {'name': 'Jane Judy', 'sex': 'Female', 'age': 28, 'married': False}

# %%
type(person1)
# Out:
# dict

# %%
person1['married']
# Out:
# True

# %%
person1['address']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 person1['address']
#
# KeyError: 'address'

# %%
person2.get("name")
# Out:
# 'Jane Judy'

# %%
person2.get("address", "Unknown")
# Out:
# 'Unknown'

# %%
'name' in person1
# Out:
# True

# %%
'address' in person1
# Out:
# False

# %%
person2['married']
# Out:
# False

# %%
person2['married'] = True

# %%
person2['married']
# Out:
# True

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
person1['address'] = '1, Shah ki Imli'

# %%
person1
# Out:
# {'name': 'John Doe',
#  'sex': 'Male',
#  'age': 32,
#  'married': True,
#  'address': '1, Shah ki Imli'}

# %%
person1.keys()
# Out:
# dict_keys(['name', 'sex', 'age', 'married', 'address'])
