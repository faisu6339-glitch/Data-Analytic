# %%
import numpy as np

# %%
var=np.array([[1,2,3],[4,5,6]])
print(var)
print(type(var))
# Out:
# [[1 2 3]
#  [4 5 6]]
# <class 'numpy.ndarray'>

# %%
var1=np.matrix([[1,2,3],[4,5,6]])
print(var1)
print(type(var1))
# Out:
# [[1 2 3]
#  [4 5 6]]
# <class 'numpy.matrix'>
