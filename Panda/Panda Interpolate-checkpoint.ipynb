# %%
import pandas as pd

# %%
var=pd.read_csv('locations.csv')
var
# Out:
#                location      continent   population  life_expectancy  \
# 0           Afghanistan           Asia   38928341.0            64.83
# 1               Albania         Europe    2877800.0            78.57
# 2                   NaN            NaN          NaN              NaN
# 3                   NaN            NaN          NaN              NaN
# 4                Angola         Africa   32866268.0            61.15
# 5                   NaN            NaN          NaN              NaN
# 6   Antigua and Barbuda  North America      97928.0            77.02
# 7             Argentina  South America   45195777.0            76.67
# 8               Armenia           Asia    2963234.0            75.09
# 9                 Aruba  North America     106766.0            76.29
# 10            Australia        Oceania   25499881.0            83.44
# 11              Austria         Europe    9006400.0            81.54
# 12           Azerbaijan           Asia   10139175.0            73.00
# ...

# %%
#Filling the NaN values only in NUMBERS

# %%
var.interpolate()
# Out:
# C:\Users\MAA\AppData\Local\Temp\ipykernel_5268\1566664964.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate()
#                location      continent   population  life_expectancy  \
# 0           Afghanistan           Asia   38928341.0        64.830000
# 1               Albania         Europe    2877800.0        78.570000
# 2                   NaN            NaN   12873956.0        72.763333
# 3                   NaN            NaN   22870112.0        66.956667
# 4                Angola         Africa   32866268.0        61.150000
# 5                   NaN            NaN   16482098.0        69.085000
# 6   Antigua and Barbuda  North America      97928.0        77.020000
# 7             Argentina  South America   45195777.0        76.670000
# 8               Armenia           Asia    2963234.0        75.090000
# ...

# %%
var.interpolate(method="linear",axis=0)
# Out:
# C:\Users\MAA\AppData\Local\Temp\ipykernel_5268\3195347084.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(method="linear",axis=0)
#                location      continent   population  life_expectancy  \
# 0           Afghanistan           Asia   38928341.0        64.830000
# 1               Albania         Europe    2877800.0        78.570000
# 2                   NaN            NaN   12873956.0        72.763333
# 3                   NaN            NaN   22870112.0        66.956667
# 4                Angola         Africa   32866268.0        61.150000
# 5                   NaN            NaN   16482098.0        69.085000
# 6   Antigua and Barbuda  North America      97928.0        77.020000
# 7             Argentina  South America   45195777.0        76.670000
# 8               Armenia           Asia    2963234.0        75.090000
# ...
